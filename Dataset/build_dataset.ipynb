# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Here we did an with the 2020 quotations, but we did the same for each years just by changing the path.

# %%
df_2020 = pd.read_json("DATA\Quotebank\quotes-2020.json.bz2", compression="bz2", chunksize=100000, lines=True, encoding='UTF-8')

# %%
selected_columns = ['aliases', 'nationality', 'occupation', 'party', 'label']
attributes = pd.read_csv('DATA/speaker_attributes_parse.csv', usecols=selected_columns)
attributes.dropna(how='all', inplace=True)
attributes.reset_index(inplace=True)
attributes.drop('index', axis=1, inplace=True)
attributes.drop_duplicates(subset=['label'], inplace=True)

# %% [markdown]
# We proceed by batch because the data is too big to fit in memory. We parse the urls to only keep the "website.com" or "www.website.com" to save memory and to have a cleaner representation. And we keep only the more useful columns to save memory too. We also remove the None speaker because the data is too large and we are only interested with the quotations with a speaker.

# %%
selected_columns = ['quoteID', 'quotation', 'speaker', 'date', 'numOccurrences', 'urls']
chunk_list = []
for batch in df_2020:
    batch = batch[selected_columns]
    batch = batch[batch['speaker'] != 'None']
    urls_parse = batch['urls'].apply(
                        lambda x: x[0][x[0].index('//') + 2:]).apply(
                        lambda y: y[:y.index('/')] if y.find('/') != -1 else 'unknown')
    batch['urls_parse'] = urls_parse
    batch.drop('urls', axis=1, inplace=True)
    chunk_list.append(batch)

df_final = pd.concat(chunk_list)

# %% [markdown]
# We merge the speaker attributes with the quotes dataset to have more information about the speaker of the quotes like the nationality, occupation and politic party.

# %%
merged = df_final.merge(attributes, how='left', left_on='speaker', right_on='label')

# %%
merged.drop('label', axis=1, inplace=True)

# %%
# Out:
#                    quoteID                                          quotation  \
# 0        2020-01-16-000088  [ Department of Homeland Security ] was livid ...
# 1        2020-01-24-000168  [ I met them ] when they just turned 4 and 7. ...
# 2        2020-01-17-000357  [ The delay ] will have an impact [ on Slough ...
# 3        2020-04-02-000239  [ The scheme ] treats addiction as an illness ...
# 4        2020-03-19-000276  [ These ] actions will allow households who ha...
# ...                    ...                                                ...
# 3443600  2020-03-03-079268  you're going to take care of the gun problem w...
# 3443601  2020-02-24-080186  you're seeing a young team that's maturing, th...
# 3443602  2020-02-07-122251  You're talking about African-Americans, right?...
# 3443603  2020-02-04-118820  You've got to sometimes take that leap of fait...
# 3443604  2020-02-24-080256  You've got to think that long term, it augurs ...
#
#                       speaker                date  numOccurrences  \
# 0                  Sue Myrick 2020-01-16 12:00:13               1
# 1         Meghan King Edmonds 2020-01-24 20:37:09               4
# 2                Dexter Smith 2020-01-17 13:03:00               1
# 3             Barry Coppinger 2020-04-02 14:18:20               1
# 4                  Ben Carson 2020-03-19 19:14:00               1
# ...                       ...                 ...             ...
# 3443600             Joe Biden 2020-03-03 15:49:51               2
# 3443601       Brendan Whittet 2020-02-24 05:00:28               1
# 3443602  Barry Michael Cooper 2020-02-07 00:00:00               1
# 3443603           Brad Gushue 2020-02-04 14:47:00              10
# 3443604           John Colley 2020-02-24 04:30:00               3
#
#                          urls_parse  \
# 0                       thehill.com
# 1                        people.com
# 2           www.sloughexpress.co.uk
# 3                 www.theweek.co.uk
# 4                   mortgageorb.com
# ...                             ...
# 3443600                 twitchy.com
# 3443601  feeds.browndailyherald.com
# 3443602        www.villagevoice.com
# 3443603           timescolonist.com
# 3443604       www.farmweekly.com.au
#
#                                                    aliases  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4        ['Benjamin Solomon Carson' 'Benjamin Solomon "...
# ...                                                    ...
# 3443600  ['Joseph Biden' 'Joseph R. Biden' 'Joseph R. B...
# 3443601                                                NaN
# 3443602                                                NaN
# 3443603                                                NaN
# 3443604                              ['Johannes Collaeus']
#
#                           nationality  \
# 0        ['United States of America']
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4        ['United States of America']
# ...                               ...
# 3443600  ['United States of America']
# 3443601  ['United States of America']
# 3443602  ['United States of America']
# 3443603                    ['Canada']
# 3443604             ['Great Britain']
#
#                                                 occupation  \
# 0                                           ['politician']
# 1                                                      NaN
# 2                                    ['basketball player']
# 3                                                      NaN
# 4        ['psychologist', 'neurosurgeon', 'politician',...
# ...                                                    ...
# 3443600     ['politician', 'lawyer', 'university teacher']
# 3443601                              ['ice hockey player']
# 3443602                     ['journalist', 'screenwriter']
# 3443603                                         ['curler']
# 3443604                   ['Catholic friar', 'theologian']
#
#                                                      party
# 0                                     ['Republican Party']
# 1                                                      NaN
# 2                                                      NaN
# 3                                         ['Labour Party']
# 4        ['Republican Party', 'Democratic Party', 'inde...
# ...                                                    ...
# 3443600                               ['Democratic Party']
# 3443601                                                NaN
# 3443602                                                NaN
# 3443603                                                NaN
# 3443604                                                NaN
#
# [3443605 rows x 10 columns]

# %%
merged.to_csv("DATA/quotes_2020_parse.csv", compression='bz2')
