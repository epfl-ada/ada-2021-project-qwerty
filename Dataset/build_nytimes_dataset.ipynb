# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from urllib.parse import *

# %% [markdown]
# Here we did for the 2020 quotations but we did the same for the other years just by replacing with the corresponding path.

# %%
df_2015 = pd.read_json("DATA\Quotebank\quotes-2020.json.bz2", compression="bz2", chunksize=100000, lines=True, encoding='UTF-8')

# %% [markdown]
# Here we create a function that allow us to extract the different topics from the nytimes urls.

# %%
def parse_url(url):
    url_parse = urlparse(url)
    start = 12
    if url_parse.netloc == 'www.nytimes.com' or url_parse.netloc == 'nytimes.com' or url_parse.netloc == 'mobile.nytimes.com' or url_parse.netloc == 'feeds.nytimes.com':
        if url_parse.netloc == 'feeds.nytimes.com':
            start = 24
        if url_parse.path[1:12] == 'interactive':
            start = 24 # for years before 2017: start = 13
        if url_parse.path[1:5] == 'live':
            return url_parse.netloc, 'live'
        if url_parse.path[1:6] == 'blogs':
            return url_parse.netloc, 'blogs'
        if url_parse.path[1:8] == 'reuters':
            start = 20
        if url_parse.path[1:9] == 'aponline':
            start = 21
        count = 0
        for letter in url_parse.path[start:]:
            if letter == '/':
                break
            count += 1
        return url_parse.netloc, url_parse.path[start:][:count]
        
    return 'www.nytimes.com', 'unknown'

# %% [markdown]
# Here we do the same like in the "build_dataset.ipynb" but additionaly we apply the parse_url on each url in the dataset to extract the topics and create a new column with it.

# %%
selected_columns = ['quoteID', 'quotation', 'speaker', 'date', 'numOccurrences', 'urls']
chunk_list = []
for batch in df_2015:
    batch = batch[selected_columns]
    urls_parse = batch['urls'].apply(
                        lambda x: x[0][x[0].index('//') + 2:]).apply(
                        lambda y: y[:y.index('/')] if y.find('/') != -1 else 'unknown')
    batch = batch[urls_parse.str.contains('nytimes')]
    batch[['urls_parse', 'topic']] = batch.apply(lambda x: parse_url(x['urls'][0]), result_type ='expand', axis=1)
    batch.drop('urls', axis=1, inplace=True)
    chunk_list.append(batch)
df_final = pd.concat(chunk_list)

# %%
df_final
# Out:
#                    quoteID                                          quotation  \
# 78       2020-04-10-002022  All the films and my life are thanks to my mot...
# 128      2020-01-09-006199  Andrew Yang's Lies About Supporting Medicare f...
# 374      2020-01-22-017789  eager to erase the image of congressional Repu...
# 562      2020-01-31-027972  How many players in the N.B.A. have a huge rol...
# 564      2020-01-01-010404  How terrifying can this human be? How afraid o...
# ...                    ...                                                ...
# 5243920  2020-04-14-060385  This is very sensitive, very difficult for our...
# 5244002  2020-02-07-100927               trying to understand my own culture.
# 5244172  2020-01-19-049886  we immediately initiated an investigation and ...
# 5244252  2020-01-26-053553                           Well, Joe, you're wrong.
# 5244295  2020-02-23-041538  We've been writing about climate change being ...
#
#                  speaker                date  numOccurrences  \
# 78         Bruce Baillie 2020-04-10 23:47:23               1
# 128          Andrew Yang 2020-01-09 01:21:54               2
# 374          Eric Cantor 2020-01-22 21:20:52               2
# 562      Brian Baldinger 2020-01-31 10:00:17               4
# 564          Simon Stone 2020-01-01 15:00:09               2
# ...                  ...                 ...             ...
# 5243920             None 2020-04-14 04:05:25               4
# 5244002             None 2020-02-07 15:00:10               2
# 5244172             None 2020-01-19 18:08:35               7
# 5244252   Bernie Sanders 2020-01-26 17:01:39              10
# 5244295    Lesley Hughes 2020-02-23 22:38:42               2
#
#                  urls_parse    topic
# 78              nytimes.com   movies
# 128         www.nytimes.com  opinion
# 374      mobile.nytimes.com       us
# 562         www.nytimes.com   sports
# 564             nytimes.com  theater
# ...                     ...      ...
# 5243920     www.nytimes.com    world
# 5244002  mobile.nytimes.com     arts
# 5244172  mobile.nytimes.com    world
# 5244252     www.nytimes.com     live
# 5244295     www.nytimes.com    world
#
# [38029 rows x 7 columns]

# %% [markdown]
# Same as "build_dataset.ipynb" to merge speaker attributes with the quotes dataset.

# %%
selected_columns = ['aliases', 'nationality', 'occupation', 'party', 'label']
attributes = pd.read_csv('DATA/speaker_attributes_parse.csv', usecols=selected_columns)
attributes.dropna(how='all', inplace=True)
attributes.reset_index(inplace=True)
attributes.drop('index', axis=1, inplace=True)
attributes.drop_duplicates(subset=['label'], inplace=True)
merged = df_final.merge(attributes, how='left', left_on='speaker', right_on='label')
merged.drop('label', axis=1, inplace=True)

# %%
merged
# Out:
#                  quoteID                                          quotation  \
# 0      2020-04-10-002022  All the films and my life are thanks to my mot...
# 1      2020-01-09-006199  Andrew Yang's Lies About Supporting Medicare f...
# 2      2020-01-22-017789  eager to erase the image of congressional Repu...
# 3      2020-01-31-027972  How many players in the N.B.A. have a huge rol...
# 4      2020-01-01-010404  How terrifying can this human be? How afraid o...
# ...                  ...                                                ...
# 38024  2020-04-14-060385  This is very sensitive, very difficult for our...
# 38025  2020-02-07-100927               trying to understand my own culture.
# 38026  2020-01-19-049886  we immediately initiated an investigation and ...
# 38027  2020-01-26-053553                           Well, Joe, you're wrong.
# 38028  2020-02-23-041538  We've been writing about climate change being ...
#
#                speaker                date  numOccurrences  \
# 0        Bruce Baillie 2020-04-10 23:47:23               1
# 1          Andrew Yang 2020-01-09 01:21:54               2
# 2          Eric Cantor 2020-01-22 21:20:52               2
# 3      Brian Baldinger 2020-01-31 10:00:17               4
# 4          Simon Stone 2020-01-01 15:00:09               2
# ...                ...                 ...             ...
# 38024             None 2020-04-14 04:05:25               4
# 38025             None 2020-02-07 15:00:10               2
# 38026             None 2020-01-19 18:08:35               7
# 38027   Bernie Sanders 2020-01-26 17:01:39              10
# 38028    Lesley Hughes 2020-02-23 22:38:42               2
#
#                urls_parse    topic               aliases  \
# 0             nytimes.com   movies                   NaN
# 1         www.nytimes.com  opinion         ['Yang Anze']
# 2      mobile.nytimes.com       us  ['Eric Ivan Cantor']
# 3         www.nytimes.com   sports                   NaN
# 4             nytimes.com  theater                   NaN
# ...                   ...      ...                   ...
# 38024     www.nytimes.com    world                   NaN
# 38025  mobile.nytimes.com     arts                   NaN
# 38026  mobile.nytimes.com    world                   NaN
# 38027     www.nytimes.com     live   ['Bernard Sanders']
# 38028     www.nytimes.com    world                   NaN
#
#                         nationality  \
# 0      ['United States of America']
# 1      ['United States of America']
# 2      ['United States of America']
# 3      ['United States of America']
# 4                               NaN
# ...                             ...
# 38024                           NaN
# 38025                           NaN
# 38026                           NaN
# 38027  ['United States of America']
# 38028                           NaN
#
#                                               occupation  \
# 0                                      ['film director']
# 1         ['entrepreneur', 'lawyer', 'political pundit']
# 2             ['politician', 'lawyer', 'businessperson']
# 3                           ['American football player']
# 4                                                    NaN
# ...                                                  ...
# 38024                                                NaN
# 38025                                                NaN
# 38026                                                NaN
# 38027  ['politician', 'journalist', 'carpenter', 'uni...
# 38028                                     ['researcher']
#
#                                                    party
# 0                                                    NaN
# 1                                   ['Democratic Party']
# 2                                   ['Republican Party']
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 38024                                                NaN
# 38025                                                NaN
# 38026                                                NaN
# 38027  ['Liberty Union Party', 'Democratic Party', 'i...
# 38028                                                NaN
#
# [38029 rows x 11 columns]

# %%
merged.to_csv("DATA/quotes_nytimes_2020_parse.csv.bz2", compression='bz2')
